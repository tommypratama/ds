# %%
import plotly.offline as offline

offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import plotly.graph_objs as go

import numpy as np

# %% [markdown]
# #### Generate a sets of 200 x and y coordinates
# These will be used in our scatter plot

# %%
n = 200

random_x = np.random.randn(n)

random_y = np.random.randn(n)

# %% [markdown]
# #### Creating a trace from a Plotly Scatter object
# This will generate points using the X and Y coordinates which we supply. The X and Y coordinates are paired by their index.
#
# Setting the mode to 'markers' will ensure that only the points are plotted, and are not connected by a line. The default mode is 'lines' where the points are connected by a line in the order of their index. i.e. (x0, y0) to (x1, y1) to (x2, y2) etc.
#
# The trace or graph is effectively a JSON object containing the details needed for a plot.

# %%
trace = go.Scatter(
    x = random_x,
    y = random_y,
    mode = 'markers'
)

trace
# Out:
# Scatter({
#     'mode': 'markers',
#     'x': array([-0.02664488,  1.3299196 ,  0.68773471,  0.54468379, -1.07236419,
#                 -0.48348455,  0.41863474,  0.56675394, -1.05499751, -1.88745987,
#                  1.11545866, -0.0580706 , -1.67005406,  1.10428937,  0.2202619 ,
#                 -1.15731163, -1.12134263, -0.21226867,  0.80841237,  0.4100206 ,
#                  0.94791278,  0.35696912,  1.11213413, -0.07705514, -0.2361236 ,
#                 -0.93055805,  1.86880122,  0.6754409 ,  1.29453637, -0.91665783,
#                 -0.97526229,  0.42357599,  1.86773109,  0.47692687, -0.59717773,
#                 -0.13606943,  0.17785364,  0.00584202,  0.48163008,  0.70591803,
#                  0.36879301, -3.0779587 , -1.46653449,  1.65378484, -0.56501089,
#                  0.45190049, -0.72681865,  1.51653365, -1.34418507, -0.34356147,
#                 -0.38609161, -0.11417283,  1.18170107, -0.76612623,  0.84818289,
#                 -0.05253393, -0.03612996, -2.18724474,  0.1363453 , -1.23326323,
#                  1.51579659, -1.34218054, -1.65502546,  1.58617993, -0.11405363,
#                 -0.993148  , -0.48123393, -1.36911601,  0.13023385,  0.442048  ,
#                 -1.13647348, -1.6832982 , -0.05143694,  0.23974173,  0.67008499,
#                 -0.99434915,  0.12756616, -1.50638828, -0.51202897,  1.60266137,
#                  0.20076565, -0.3950024 , -0.57606827,  0.65103071,  0.22196004,
#                 -0.04418298,  1.37043061,  1.24428241,  0.18578716, -0.28599255,
#                 -0.78642339,  0.49486703, -0.07907793, -0.74884839,  0.92174791,
#                 -0.62728725, -0.85728942,  0.80037317,  0.00875077, -1.04593457,
#                 -1.16851569, -0.18804923,  0.53920544,  0.93460107, -1.10123013,
#                  0.22189472,  0.0807302 ,  1.0006417 ,  2.04136985, -0.07992394,
#                  1.08469255, -2.05837879, -0.87603011, -0.77977995, -0.40178211,
#                  1.30570657,  0.75873226,  0.46431192, -0.73244727, -0.47702144,
#                 -0.20039142, -0.87919073,  0.57807356, -1.28813707, -0.00662584,
#                  0.65900388, -1.98017697,  1.19631224, -0.67025199, -0.10555202,
#                 -1.85687588,  0.01222516, -0.21271207,  0.62864471, -0.77201653,
#                  1.97295731,  1.43053648, -0.72063147,  0.40862451, -0.24198699,
#                  0.13229982,  0.59128376,  0.39100058,  1.77129173, -0.8059024 ,
#                 -1.10709377, -2.2353814 , -1.92906511,  0.21116255,  0.89939433,
#                 -0.98531144,  0.15778776,  0.90241957,  0.63233225,  0.61450347,
244282408965034, 0.18578715785695699, -0.28599255101952487, -0.7864233886569613, 0.49486703272711163, -0.07907792770918412, -0.7488483854613046, 0.9217479100520343, -0.6272872469424495, -0.8572894217756064, 0.8003731695972336, 0.008750768224017748, -1.0459345683839212, -1.1685156891435364, -0.18804923383931207, 0.5392054433372219, 0.934601073997217, -1.1012301305611563, 0.22189471810416217, 0.08073020198026397, 1.0006416984172344, 2.041369848454142, -0.07992394195332309, 1.08469255137482, -2.058378791840505, -0.8760301121594314, -0.7797799489370252, -0.4017821054007903, 1.3057065746201855, 0.7587322639601585, 0.46431191633038404, -0.7324472737906867, -0.47702143609140074, -0.20039141962103915, -0.8791907333714901, 0.5780735554729279, -1.2881370745430043, -0.0066258404244877635, 0.6590038790676823, -1.9801769686674289, 1.1963122416199528, -0.6702519869795802, -0.10555201595894104, -1.8568758809821584, 0.012225159435785166, -0.21271206866645212, 0.6286447101947613, -0.7720165258731492, 1.97295730993335, 1.4305364758640693, -0.7206314665872531, 0.4086245125555517, -0.24198698994755782, 0.1322998246729065, 0.5912837640689873, 0.39100058096483087, 1.7712917334681753, -0.8059023993734804, -1.1070937732056974, -2.23538140387949, -1.929065114804899, 0.21116255236837428, 0.8993943307236426, -0.9853114404503525, 0.15778776113747403, 0.9024195690567661, 0.6323322485109578, 0.6145034690882103, -1.7489570513639217, 0.019313607682193278, -0.2430665388339779, 0.15941778159915224, -0.662139726571038, -0.15612094005653643, -0.13089780769033996, 0.5668605954802459, -0.4476880183694007, 1.4742380356405878, -0.12071733466073731, 0.7335960923467525, 0.13321763198001188, 0.7745426816462831, -0.6177137927674001, 0.933592630028029, 1.6456251106505493, 0.9975189793564909, 1.3627045584187998, 1.3786803773151095, 1.1095926309351731, 1.7320904179072665, 0.25182025941792086, 0.031745713349628904, -1.3615287266573728, -0.6602538670467683, -0.9254401826408394, 0.6721277827107967, 1.6424460490904988, 0.1573936166402617, 0.914194809591859, 0.20996558562771211, 0.078591013188654 ...

# %% [markdown]
# ### Multiple Scatter plots in one plot
# Here we produce multiple graphs on the same plot. We do that by having a single set of x coordinates shared by 3 sets of y coordinates. We space out the y values for each graph so that they do not overlap on the plot.

# %% [markdown]
# #### Generate the X coordinates
# We will create 50 points in each graph. Start off by creating 50 evenly spaced x values in the interval (0,1). These values are ordered (so that lines connecting them move left to right rather than all over the place)

# %%
n = 50

random_x = np.linspace(0, 1, n)

# %% [markdown]
# #### Generate 3 sets of Y coordinates
# These are spaced with offsets of 5 so that they do not overlap. There is no ordering of values here.

# %%
random_y0 = np.random.randn(n)+5

random_y1 = np.random.randn(n)

random_y2 = np.random.randn(n)-5

# %% [markdown]
# #### The first trace/graph contains only markers
# These will only be points which are not connected by a line. A name is assigned to the trace - this will appear in the legend of the plot

# %%
trace0 = go.Scatter(
    x = random_x,
    y = random_y0,
    mode = 'markers'
)

# %% [markdown]
# #### The second trace has only a line
# The points are connected by a line, but without markers for the points

# %%
trace1 = go.Scatter(
    x = random_x,
    y = random_y1,
    mode = 'lines'
)

# %% [markdown]
# #### The third trace has both markers and a connecting line

# %%
trace2 = go.Scatter(
    x = random_x,
    y = random_y2,
    mode = 'lines+markers'
)

# %% [markdown]
# #### The data for our plot now comprises three traces
# These are all contained in a list which is used by the plot

# %%
data = [trace0, trace1, trace2]

# %% [markdown]
# #### Generate the plot
# Plotly is smart enough to create a legend automatically, though it has assigned some default names for the traces.

# %%
offline.iplot(data)
# Out:
# <div>
#
#
#             <div id="5f24dbb4-7ff4-4b10-9665-afe3ba24a600" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5f24dbb4-7ff4-4b10-9665-afe3ba24a600")) {
#                     Plotly.newPlot(
#                         '5f24dbb4-7ff4-4b10-9665-afe3ba24a600',
#                         [{"mode": "markers", "type": "scatter", "uid": "473153c8-202b-46a2-885f-fc7bdc5e14c0", "x": [0.0, 0.02040816326530612, 0.04081632653061224, 0.061224489795918366, 0.08163265306122448, 0.1020408163265306, 0.12244897959183673, 0.14285714285714285, 0.16326530612244897, 0.18367346938775508, 0.2040816326530612, 0.22448979591836732, 0.24489795918367346, 0.26530612244897955, 0.2857142857142857, 0.3061224489795918, 0.32653061224489793, 0.3469387755102041, 0.36734693877551017, 0.3877551020408163, 0.4081632653061224, 0.42857142857142855, 0.44897959183673464, 0.4693877551020408, 0.4897959183673469, 0.5102040816326531, 0.5306122448979591, 0.5510204081632653, 0.5714285714285714, 0.5918367346938775, 0.6122448979591836, 0.6326530612244897, 0.6530612244897959, 0.673469387755102, 0.6938775510204082, 0.7142857142857142, 0.7346938775510203, 0.7551020408163265, 0.7755102040816326, 0.7959183673469387, 0.8163265306122448, 0.836734693877551, 0.8571428571428571, 0.8775510204081632, 0.8979591836734693, 0.9183673469387754, 0.9387755102040816, 0.9591836734693877, 0.9795918367346939, 1.0], "y": [6.740198308443553, 5.2323347194726155, 4.464484993492262, 5.129700378759879, 4.59398017068991, 4.545294192854667, 4.208862293581039, 4.46466934273242, 2.069637897708686, 2.2645852722012183, 6.518667375201003, 5.128264373270766, 5.295534228958835, 3.8746786430907427, 5.442771665038662, 5.065899935185167, 7.180680127440018, 5.906793387527486, 5.55633567916927, 4.821229585944479, 4.24549072196, 5.019477124316843, 5.297139531912705, 5.304712302552064, 6.390886976852433, 5.512867867915007, 3.4960937051483123, 4.008074077605791, 5.875608863254479, 4.104088544033649, 5.9518557162416155, 6.375365876989667, 4.8291490649368605, 5.359991370925539, 4.948157380473446, 5.379137849353482, 4.494894460877427, 4.987504831727565, 4.513731507809977, 4.325597595488882, 4.062231805090972, 5.879461579043932, 5.032481557312211, 5.878295698250342, 5.371696760688939, 3.4740609788370556, 5.042356063026337, 4.00061478823943, 5.192254893350538, 4.34011482105179]}, {"mode": "lines", "type": "scatter", "uid": "2e74a307-6fc0-4f40-844c-37b8bda77460", "x": [0.0, 0.02040816326530612, 0.04081632653061224, 0.061224489795918366, 0.08163265306122448, 0.1020408163265306, 0.12244897959183673, 0.14285714285714285, 0.16326530612244897, 0.18367346938775508, 0.2040816326530612, 0.22448979591836732, 0.24489795918367346, 0.26530612244897955, 0.2857142857142857, 0.3061224489795918, 0.32653061224489793, 0.3469387755102041, 0.36734693877551017, 0.3877551020408163, 0.4081632653061224, 0.42857142857142855, 0.44897959183673464, 0.4693877551020408, 0.4897959183673469, 0.5102040816326531, 0.5306122448979591, 0.5510204081632653, 0.5714285714285714, 0.5918367346938775, 0.6122448979591836, 0.6326530612244897, 0.6530612244897959, 0.673469387755102, 0.6938775510204082, 0.7142857142857142, 0.7346938775510203, 0.7551020408163265, 0.7755102040816326, 0.7959183673469387, 0.8163265306122448, 0.836734693877551, 0.8571428571428571, 0.8775510204081632, 0.8979591836734693, 0.9183673469387754, 0.9387755102040816, 0.9591836734693877, 0.9795918367346939, 1.0], "y": [1.5142706425731858, 1.0970801125241778, -0.6545330619745654, -0.20299878088576478, 1.2409549336908268, 0.910412762825909, 0.027359855375704366, -0.09234624139303044, 1.2484168934303381, 2.3530306668629475, -2.855074724659463, 0.4628175634595008, 0.017129892262773026, 0.27177382491502294, -1.3125044125407224, 1.1798125111368658, 0.20717600841231154, 2.0087900256094064, -0.7545060155536083, 0.19785662163641315, -0.45717938030993704, -0.49099632065251525, 0.11241701040470185, 0.8371786457058548, 1.0685139209294652, 0.5129443934248896, 0.315398621585879, 0.49967018177555617, 0.07503412414579752, -0.3264519648285288, 1.025374743154474, -0.42056827043682754, 0.5244228211076771, -0.14278400213530557, 1.4653752519422292, 0.22757775460875032, -0.7242456280275115, 0.8148445403933776, -1.3595324083310036, 2.4358103695391673, 0.2942479825623336, 0.6391495306225 ...
#                         {},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('5f24dbb4-7ff4-4b10-9665-afe3ba24a600');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# # Style Scatter Plots
# We can customize the look of the scatter plots by configuring each of its components. Here, we show how we can define the markers, lines, graph names, the axes and set a title for our plot.
#
# We also define a layout and figure instead of plotting with only the data. A figure object comprises the data plus a layout.

# %% [markdown]
# #### Define a style for the marker
# Among other attributes, we can set the size and color of markers. There are different ways to set the colors, but here we just use the names of some colors.

# %%
marker_style = dict(size = 10,
                    color = 'orange')

# %% [markdown]
# #### Define the line style
# Here, we set the color and width

# %%
line_style = dict(width = 3, 
                  color = 'khaki')

# %% [markdown]
# #### Define the first trace
# It's the same as the previous one, but with a customised marker style. We also set a name for the graph which will appear in the legend (instead of "trace 0")

# %%
trace0 = go.Scatter(
    x = random_x,
    y = random_y0,
    mode = 'markers',
    marker = marker_style,
    name = 'Markers only'
)

# %% [markdown]
# #### The second trace uses the line style
# We also set a name for this trace

# %%
trace1 = go.Scatter(
    x = random_x,
    y = random_y1,
    mode = 'lines',
    line = line_style,
    name = 'Lines only'
)

# %% [markdown]
# #### Define the third trace
# This one uses both the line style and marker style

# %%
trace2 = go.Scatter(
    x = random_x,
    y = random_y2,
    mode = 'lines+markers',
    marker = marker_style,
    line = line_style,
    name = 'Markers + Lines'
)

# %% [markdown]
# #### Each plot contains a layout which can be configured
# The layout has several configurable attributes including the title and the axes. For the axes, we set the width for the zero line

# %%
layout = dict(title = 'Styled Scatter',
              yaxis = dict(zerolinewidth = 4),
              xaxis = dict(zerolinewidth = 4)
             )

# %% [markdown]
# #### Define the data for our plot
# Just as before, it contains the 3 traces we have created. This time with the additional styling.

# %%
data = [trace0, trace1, trace2]

# %% [markdown]
# #### Define a figure object
# A figure is simply an object which contains the data and the layout definition for a plot. This time we will plot a figure object instead of a data object.

# %%
fig = dict(data = data, 
           layout = layout)

# %% [markdown]
# #### Plot the figure

# %%
offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="886c5cbf-de1e-430a-aaaa-7d111004b997" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("886c5cbf-de1e-430a-aaaa-7d111004b997")) {
#                     Plotly.newPlot(
#                         '886c5cbf-de1e-430a-aaaa-7d111004b997',
#                         [{"marker": {"color": "orange", "size": 10}, "mode": "markers", "name": "Markers only", "type": "scatter", "uid": "01fd01cf-9dbf-4739-877f-82d34bd0b410", "x": [0.0, 0.02040816326530612, 0.04081632653061224, 0.061224489795918366, 0.08163265306122448, 0.1020408163265306, 0.12244897959183673, 0.14285714285714285, 0.16326530612244897, 0.18367346938775508, 0.2040816326530612, 0.22448979591836732, 0.24489795918367346, 0.26530612244897955, 0.2857142857142857, 0.3061224489795918, 0.32653061224489793, 0.3469387755102041, 0.36734693877551017, 0.3877551020408163, 0.4081632653061224, 0.42857142857142855, 0.44897959183673464, 0.4693877551020408, 0.4897959183673469, 0.5102040816326531, 0.5306122448979591, 0.5510204081632653, 0.5714285714285714, 0.5918367346938775, 0.6122448979591836, 0.6326530612244897, 0.6530612244897959, 0.673469387755102, 0.6938775510204082, 0.7142857142857142, 0.7346938775510203, 0.7551020408163265, 0.7755102040816326, 0.7959183673469387, 0.8163265306122448, 0.836734693877551, 0.8571428571428571, 0.8775510204081632, 0.8979591836734693, 0.9183673469387754, 0.9387755102040816, 0.9591836734693877, 0.9795918367346939, 1.0], "y": [6.740198308443553, 5.2323347194726155, 4.464484993492262, 5.129700378759879, 4.59398017068991, 4.545294192854667, 4.208862293581039, 4.46466934273242, 2.069637897708686, 2.2645852722012183, 6.518667375201003, 5.128264373270766, 5.295534228958835, 3.8746786430907427, 5.442771665038662, 5.065899935185167, 7.180680127440018, 5.906793387527486, 5.55633567916927, 4.821229585944479, 4.24549072196, 5.019477124316843, 5.297139531912705, 5.304712302552064, 6.390886976852433, 5.512867867915007, 3.4960937051483123, 4.008074077605791, 5.875608863254479, 4.104088544033649, 5.9518557162416155, 6.375365876989667, 4.8291490649368605, 5.359991370925539, 4.948157380473446, 5.379137849353482, 4.494894460877427, 4.987504831727565, 4.513731507809977, 4.325597595488882, 4.062231805090972, 5.879461579043932, 5.032481557312211, 5.878295698250342, 5.371696760688939, 3.4740609788370556, 5.042356063026337, 4.00061478823943, 5.192254893350538, 4.34011482105179]}, {"line": {"color": "khaki", "width": 3}, "mode": "lines", "name": "Lines only", "type": "scatter", "uid": "9d38882d-a0e6-4476-833f-614d33d15a12", "x": [0.0, 0.02040816326530612, 0.04081632653061224, 0.061224489795918366, 0.08163265306122448, 0.1020408163265306, 0.12244897959183673, 0.14285714285714285, 0.16326530612244897, 0.18367346938775508, 0.2040816326530612, 0.22448979591836732, 0.24489795918367346, 0.26530612244897955, 0.2857142857142857, 0.3061224489795918, 0.32653061224489793, 0.3469387755102041, 0.36734693877551017, 0.3877551020408163, 0.4081632653061224, 0.42857142857142855, 0.44897959183673464, 0.4693877551020408, 0.4897959183673469, 0.5102040816326531, 0.5306122448979591, 0.5510204081632653, 0.5714285714285714, 0.5918367346938775, 0.6122448979591836, 0.6326530612244897, 0.6530612244897959, 0.673469387755102, 0.6938775510204082, 0.7142857142857142, 0.7346938775510203, 0.7551020408163265, 0.7755102040816326, 0.7959183673469387, 0.8163265306122448, 0.836734693877551, 0.8571428571428571, 0.8775510204081632, 0.8979591836734693, 0.9183673469387754, 0.9387755102040816, 0.9591836734693877, 0.9795918367346939, 1.0], "y": [1.5142706425731858, 1.0970801125241778, -0.6545330619745654, -0.20299878088576478, 1.2409549336908268, 0.910412762825909, 0.027359855375704366, -0.09234624139303044, 1.2484168934303381, 2.3530306668629475, -2.855074724659463, 0.4628175634595008, 0.017129892262773026, 0.27177382491502294, -1.3125044125407224, 1.1798125111368658, 0.20717600841231154, 2.0087900256094064, -0.7545060155536083, 0.19785662163641315, -0.45717938030993704, -0.49099632065251525, 0.11241701040470185, 0.8371786457058548, 1.0685139209294652, 0.5129443934248896, 0.315398621585879, 0.49967018177555617, 0.07503412414579752, -0.3264519648285288, 1.025374743154474, -0.42056827043682754, 0.5244228211076771, -0.14278400213530557, 1.4653752519422292, 0.2275777 ...
#                         {"title": {"text": "Styled Scatter"}, "xaxis": {"zerolinewidth": 4}, "yaxis": {"zerolinewidth": 4}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('886c5cbf-de1e-430a-aaaa-7d111004b997');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clear

# %% [markdown]
# ### Using a color scale
# A color scale will set the color of an object (e.g. a marker) according to a particular value. This will allow the visualization of an extra dimension in a plot (a 3rd dimension in a 2D and 4th in a 3D plot).

# %% [markdown]
# #### Define x, y and z values
# Similar to the scatter plot we plotted right in the beginning, this time with an added Z dimension

# %%
n = 200

random_x = np.random.randn(n)

random_y = np.random.randn(n)

random_z = np.random.randn(n)

# %% [markdown]
# #### Colorscales
# Plotly uses the Matplotlib colormaps for its colorscales. The list of available colorscales can be found here:
# https://matplotlib.org/examples/color/colormaps_reference.html
#
# The way this works is that for a given range of values (in our example, the range of Z values) the colorscale is created such that a value will correspond to a color on the colorscale.

# %% [markdown]
# #### Generate the trace with the details for the colorscale
# Here, the we define our scatter trace to color the markers according to the value of the Z coordinate, and using the colorscale 'Magma'.
#
# showscale = True will ensure the colorscale is portrayed on the plot.
#
# We also define the text which will be visible when we hover over a point. We set this to the Z value of the point so that we can match it to the color in the colorscale.

# %%
trace = go.Scatter(
    x = random_x,
    y = random_y,
    mode = 'markers',
    marker= dict(size = 14,
                 color = random_z,
                 colorscale = 'Blues',
                 showscale = True),
    text = random_z
)

# %%
data = [trace]

# %% [markdown]
# #### Define the layout
# The Layout can also be defined using the go.Layout object rather than a dictionary.
#
# By default, when hovering over a graph, the y value is displayed near the cursor, and the x value near the X axis. This is when the hovermode is 'x'.
#
# Setting the hovermode to 'y' will cause the x value to be displayed at the cursor and y value on the Y axis. We use the 'closest' hovermode to display the (x,y) and hover text of the closest marker from the cursor.

# %%
layout = go.Layout(title = 'Scatter with Colorscale',
                   hovermode = 'closest')

# %% [markdown]
# #### Define the figure
# Like the layout, there is also a go.Figure object

# %%
fig = go.Figure(data = data, 
                layout = layout)

# %% [markdown]
# #### Plot the data
# Hover over the markers to view the Z value and match it to the colorscale on the right

# %%
offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="3c092106-5624-41c9-a6f5-cf51bff5a410" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3c092106-5624-41c9-a6f5-cf51bff5a410")) {
#                     Plotly.newPlot(
#                         '3c092106-5624-41c9-a6f5-cf51bff5a410',
#                         [{"marker": {"color": [-0.6420103924322291, -0.3045612906586993, 0.2136702369348243, -0.07565219082536531, -1.558623353306264, 0.3525121534024281, 0.44203885112371016, -0.19086286225601765, 0.8177460604403088, 0.25330822958356375, -0.6704205912113397, 1.5112771873073334, -0.5211109116362335, 0.6320574877486983, -0.791244908739466, -0.2113349115971415, -0.7809441189534422, -0.35157911207836806, -1.1357008790747662, -0.8546089794518867, 2.0129226441181896, 1.7630185166060917, 0.28420751130904104, -0.11304652657369686, -0.6061360052205883, -0.608951464796769, -0.38128536805473406, 0.40358389939478495, 1.024079750843246, 0.17675046111674467, -0.8569100995538255, -1.4979235926817958, 0.087367140010404, -0.9175457100013579, 0.8326588131381084, 1.5125998744616127, 0.595820617869565, 0.15351499708072652, -0.6247338812114017, -0.38258821189228537, -0.503848409143316, -1.1509451497367829, -0.3784709571440455, -1.1302445552376332, -0.5845329571886524, -0.8810148598568874, 0.03044939849923936, 0.884134612945656, -0.34419198825375
head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %% [markdown]
# #### Generate the trace
#
# The data we will plot includes:
# * State on the X axis
# * Year on the Y axis
# * Honey production (lbs) represented by a color from the colorscale
#
# We use the Rainbox colorscale in this example. The opacity of each of the markers can also be set.
#
# This allows us to assess just by looking at the plot what the honey production was for a particular year for a state. So we can spot any changes in honey production quite easily

# %%
trace= go.Scatter(
    
         x = honey_data['state'],
        
         y = honey_data['year'],
    
         mode = 'markers',
    
         marker = dict(size= 14,
                    color=honey_data['totalprod'],
                    colorscale='Rainbow',
                    showscale=True,
                    opacity= 0.5
                   ),
    
        text = honey_data['totalprod']
)

# %%
data=[trace]

# %% [markdown]
# #### Define the layout

# %%
layout= go.Layout(
    
    title= 'Honey production the United States',
    
    hovermode= 'closest',
    
    xaxis= dict(title= 'States'),
    
    yaxis=dict(title= 'Honey Production')
)

# %%
fig= go.Figure(data=data, 
               layout=layout)

# %%
offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="be7abd47-32a5-48a4-83db-4762698a4276" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("be7abd47-32a5-48a4-83db-4762698a4276")) {
#                     Plotly.newPlot(
#                         'be7abd47-32a5-48a4-83db-4762698a4276',
#                         [{"marker": {"color": [1136000.0, 3300000.0, 3445000.0, 37350000.0, 1944000.0, 22540000.0, 4200000.0, 944000.0, 6000000.0, 639000.0, 828000.0, 3900000.0, 736000.0, 150000.0, 4551000.0, 260000.0, 308000.0, 6800000.0, 11060000.0, 1548000.0, 1518000.0, 14030000.0, 4480000.0, 460000.0, 539000.0, 770000.0, 5200000.0, 472000.0, 29440000.0, 1404000.0, 204000.0, 2250000.0, 1716000.0, 21375000.0, 448000.0, 7007000.0, 1740000.0, 384000.0, 296000.0, 2958000.0, 330000.0, 8099000.0, 2760000.0, 1156000.0, 3224000.0, 4628000.0, 27900000.0, 2052000.0, 23256000.0, 3315000.0, 640000.0, 5760000.0, 594000.0, 810000.0, 2600000.0, 871000.0, 150000.0, 5472000.0, 308000.0, 276000.0, 6205000.0, 11890000.0, 1314000.0, 1560000.0, 8540000.0, 4466000.0, 405000.0, 440000.0, 780000.0, 4830000.0, 414000.0, 26775000.0, 1480000.0, 270000.0, 2565000.0, 1680000.0, 23296000.0, 408000.0, 8748000.0, 1170000.0, 396000.0, 245000.0, 2600000.0, 234000.0, 6000000.0, 2664000.0, 1248000.0, 2360000.0, 4836000.0, 30800000.0, 1740000.0, 24360000.0, 3135000.0, 784000.0, 4700000.0, 488000.0, 520000.0, 2010000.0, 1020000.0, 192000.0, 4042000.0, 231000.0, 276000.0, 5400000.0, 13500000.0, 1224000.0, 1725000.0, 10912000.0, 4350000.0, 350000.0, 385000.0, 960000.0, 4640000.0, 539000.0, 34500000.0, 1170000.0, 245000.0, 2448000.0, 1125000.0, 28435000.0, 549000.0, 8295000.0, 984000.0, 413000.0, 294000.0, 2808000.0, 378000.0, 7560000.0, 3627000.0, 1022000.0, 2537000.0, 4900000.0, 28060000.0, 1430000.0, 22000000.0, 3135000.0,