# %% [markdown]
# #### Import the required objects

# %%
from bokeh.plotting import figure
from bokeh.io import output_notebook, show

# %% [markdown]
# #### Run in output_notebook() mode
# From now on, all plots will be generated inline

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="87f6a5d4-ffb7-429e-b36f-a84f662c8644">Loading BokehJS ...</span>
#     </div>

# %%
p = figure(plot_width = 600, 
           plot_height = 300)

# %% [markdown]
# #### Generating circular points on the plot
# Use the circle glyph in order to mark points on the graph as round dots. Here, we pass a list of X and Y coordinates

# %%
p.circle([1, 2, 3, 4, 5], 
         [6, 7, 3, 4, 5])
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='fbf45cdb-4a6a-48f1-9b29-e771cae2355f',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='6fe209cd-7056-4dba-988e-671edc8139cb',
#         callback=None,
#         data={'x': [1, 2, 3, 4, 5], 'y': [6, 7, 3, 4, 5]},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='df181fc8-9796-4c27-95d4-dc7f76c7945e',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='8bba1468-e1de-46fc-a1c1-0a875e241986',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.markers.Circle(
#         id='0761cefb-3bab-4a93-9143-d38d1d1eed1f',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 1.0},
#         fill_color={'value': '#1f77b4'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 1.0},
#         line_cap='butt',
#         line_color={'value': '#1f77b4'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         radius=None,
#         radius_dimension='x',
#         size={'value': 4, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.markers.Circle(
#         id='9ac0c5f6-092c-445f-bc69-b368045072ef',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 0.1},
#         fill_color={'value': '#1f77b4'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 0.1},
#         line_cap='butt',
#         line_color={'value': '#1f77b4'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         radius=None,
#         radius_dimension='x',
#         size={'value': 4, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='aeca2030-3297-4683-b33a-23fa65c85615',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='6fe209cd-7056-4dba-988e-671edc8139cb',
#             callback=None,
#             data={'x': [1, 2, 3, 4, 5], 'y': [6, 7, 3, 4, 5]},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='df181fc8-9796-4c27-95d4-dc7f76c7945e',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='8bba1468-e1de-46fc-a1c1-0a875e241986',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %%
show(p)
# Out:
#   <div class="bk-root" id="e85ccb5c-81db-4231-b2ab-b0beeccd4905"></div>

# %% [markdown]
# #### Configure the plot
# * size sets the diameter of the circle in screen space units (default is 4)
# * color will change the color of the circle
# * alpha sets the transparency (0 == fully transparent, 1 == perfectly opaque)

# %%
p = figure(plot_width = 600, 
           plot_height = 300)

# %%
p.circle([1, 2, 3, 4, 5], 
         [6, 7, 3, 4, 5], 
         
         size = 20, 
         
         color = 'maroon', 
         alpha = 0.5)
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='73182994-03f1-41f5-b059-2b5b09d80ff7',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='c1959a28-323a-453f-b0d2-7cf80a510315',
#         callback=None,
#         data={'x': [1, 2, 3, 4, 5], 'y': [6, 7, 3, 4, 5]},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='e14b9760-a992-4ebf-b9f5-cb63ea4faa28',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='86918401-ab3e-4671-ade4-141f9a5f26e4',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.markers.Circle(
#         id='4ecc51da-0d8c-488d-a60c-0bbe50e4edeb',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 0.5},
#         fill_color={'value': 'maroon'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 0.5},
#         line_cap='butt',
#         line_color={'value': 'maroon'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         radius=None,
#         radius_dimension='x',
#         size={'value': 20, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.markers.Circle(
#         id='c880b532-d827-4a37-8785-b5de3d204a5f',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 0.1},
#         fill_color={'value': '#1f77b4'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 0.1},
#         line_cap='butt',
#         line_color={'value': '#1f77b4'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         radius=None,
#         radius_dimension='x',
#         size={'value': 20, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='e8340ddf-cc3f-4d8a-97c0-a0bcf4338a89',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='c1959a28-323a-453f-b0d2-7cf80a510315',
#             callback=None,
#             data={'x': [1, 2, 3, 4, 5], 'y': [6, 7, 3, 4, 5]},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='e14b9760-a992-4ebf-b9f5-cb63ea4faa28',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='86918401-ab3e-4671-ade4-141f9a5f26e4',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %% [markdown]
# * Here I specifically mentioned output should be in notebook, thats why it is showing the output here
# * If we will define output_notebook in one notebook, it will always give output on the notebook
# * Also generate output that loads BokehJS from CDN, by passing the argument mode="cdn" to the output_file() function

# %%
show(p)
# Out:
#   <div class="bk-root" id="e08390c1-5f7d-408f-905b-42354ef766b7"></div>

# %% [markdown]
# #### The figure can be updated to include multiple glyphs
# Here, we just add a line to the existing figure

# %%
p.line([1, 2, 3, 4, 5], 
       [4, 3, 5, 6, 5])
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='4658e4c1-392c-4896-99d1-9a2d2fe7b1de',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='b67b222a-350f-4952-9972-d55b02f50de4',
#         callback=None,
#         data={'x': [1, 2, 3, 4, 5], 'y': [4, 3, 5, 6, 5]},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='dd3dd13c-21b2-48a4-8475-e91f65b1e01f',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='1511bf95-1789-48a2-a5ac-f3fffce17b05',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.glyphs.Line(
#         id='8663ede1-e91a-4d07-8379-3d0347102cb1',
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha=1.0,
#         line_cap='butt',
#         line_color='#1f77b4',
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width=1,
#         name=None,
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.glyphs.Line(
#         id='1cdaecd0-ca51-49a9-85d2-278912d37315',
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha=0.1,
#         line_cap='butt',
#         line_color='#1f77b4',
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width=1,
#         name=None,
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='47a56bab-f56f-438b-ac0c-a95a963215ac',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='b67b222a-350f-4952-9972-d55b02f50de4',
#             callback=None,
#             data={'x': [1, 2, 3, 4, 5], 'y': [4, 3, 5, 6, 5]},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='dd3dd13c-21b2-48a4-8475-e91f65b1e01f',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='1511bf95-1789-48a2-a5ac-f3fffce17b05',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %% [markdown]
# #### The line gets added to the circle markers already on the figure

# %%
show(p)
# Out:
#   <div class="bk-root" id="8f72e37a-b78b-49a2-b25c-5b14febf68a5"></div>

# %% [markdown]
# ## Different kinds of glyphs
# A bokeh figure supports a number of different glyphs, some of which are covered here. They all require a set of X and Y coordinates and can be configured to have a specific size, color, alpha etc.

# %% [markdown]
# ### Markers
# We take a look at some of the plotly marker styles

# %% [markdown]
# #### Create a new figure
# For this one, we specify a title

# %%
p = figure(plot_width = 600, 
           plot_height = 300, 
           
           title='Markers')

# %% [markdown]
# #### Plotly allows markers to be asterisks
# The color can be a named css color. For a full list, visit this page: <br />
# https://htmlcolorcodes.com/color-names/

# %%
p.asterisk([1, 2, 3, 4, 5], 
           [6, 7, 3, 4, 5], 
           
           size = 15, 
           color = 'green')
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='e1f34924-8cfc-4254-a11b-c4d8851d0a38',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='54ceba69-ecde-4dc0-bb40-497294bea351',
#         callback=None,
#         data={'x': [1, 2, 3, 4, 5], 'y': [6, 7, 3, 4, 5]},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='0c21e4fc-8d47-47c1-a447-327721b9bbfa',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='c00747e5-b346-4299-bb63-2e6716ffc00d',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.markers.Asterisk(
#         id='a2792bc7-2722-4bf4-b18a-98d5eaa28f4a',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 1.0},
#         fill_color={'value': 'green'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 1.0},
#         line_cap='butt',
#         line_color={'value': 'green'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         size={'value': 15, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.markers.Asterisk(
#         id='7a613ec4-8b69-43f6-ab2d-ae0228257070',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 0.1},
#         fill_color={'value': '#1f77b4'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 0.1},
#         line_cap='butt',
#         line_color={'value': '#1f77b4'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         size={'value': 15, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='6b4c20b2-b7ab-4726-b951-17ba8ca37752',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='54ceba69-ecde-4dc0-bb40-497294bea351',
#             callback=None,
#             data={'x': [1, 2, 3, 4, 5], 'y': [6, 7, 3, 4, 5]},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='0c21e4fc-8d47-47c1-a447-327721b9bbfa',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='c00747e5-b346-4299-bb63-2e6716ffc00d',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %% [markdown]
# #### Diamond markers
# * The angle of markers can also be set (the default unit is radians, where 1 radian is about 57 degrees)
# * The color can also be specified in hexadecimal notation

# %%
p.diamond([1, 2, 3, 4, 5], 
          [5, 4, 6, 7, 3], 
           
          size = 20, 
          color = '#EE82EE',
          angle = 0.8)
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='ec24b042-0228-4bbf-919c-2c8311b61d75',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='022847c7-a614-4a66-ab87-0a78ec1dbce4',
#         callback=None,
#         data={'x': [1, 2, 3, 4, 5], 'y': [5, 4, 6, 7, 3]},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='8fea8fe1-db73-4051-ac67-ae92f3498ad7',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='4f61b9ef-5dfb-43f0-a14d-4ba5fb41f2dd',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.markers.Diamond(
#         id='6eb76da6-57cf-42ff-8a5b-b441a6a5b6ae',
#         angle={'value': 0.8, 'units': 'rad'},
#         fill_alpha={'value': 1.0},
#         fill_color={'value': '#EE82EE'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 1.0},
#         line_cap='butt',
#         line_color={'value': '#EE82EE'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         size={'value': 20, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.markers.Diamond(
#         id='bdfe91c1-1bf0-4f9d-9974-8d8485dfd872',
#         angle={'value': 0.8, 'units': 'rad'},
#         fill_alpha={'value': 0.1},
#         fill_color={'value': '#1f77b4'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 0.1},
#         line_cap='butt',
#         line_color={'value': '#1f77b4'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         size={'value': 20, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='1eb0e292-90a8-46f7-939a-477119c8ad77',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='022847c7-a614-4a66-ab87-0a78ec1dbce4',
#             callback=None,
#             data={'x': [1, 2, 3, 4, 5], 'y': [5, 4, 6, 7, 3]},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='8fea8fe1-db73-4051-ac67-ae92f3498ad7',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='4f61b9ef-5dfb-43f0-a14d-4ba5fb41f2dd',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %% [markdown]
# #### Square markers
# * the color property sets a single color for both the boundary line of the shape and the inside. Here, we configure those individually
# * the color can also be denoted by rgb notation
# * we can specify the width of the marker boundary line (default is 1)

# %%
p.square([1, 2, 3, 4, 5], 
         [4, 6, 5, 3, 5], 
           
         size = 20,
         
         fill_color = 'rgb(255, 255, 0)',
         line_color = 'rgb(0, 100, 0)', 
         
         line_width = 2)
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='3dc37064-e28c-4b41-b9f0-6c5a301b5d90',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='c2783ffe-73bf-4a34-a54b-27e1f8bc8e57',
#         callback=None,
#         data={'x': [1, 2, 3, 4, 5], 'y': [4, 6, 5, 3, 5]},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='43a905a5-23d4-4d76-af82-ac606c9ded3b',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='651b613e-f6cd-413d-926e-2d587480de7b',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.markers.Square(
#         id='759df169-2f59-408b-9f44-4646d06a726e',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 1.0},
#         fill_color='rgb(255, 255, 0)',
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 1.0},
#         line_cap='butt',
#         line_color='rgb(0, 100, 0)',
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 2},
#         name=None,
#         size={'value': 20, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.markers.Square(
#         id='c1128b5e-e02f-4dcf-b9fe-d77ed312e5d5',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 0.1},
#         fill_color={'value': '#1f77b4'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 0.1},
#         line_cap='butt',
#         line_color={'value': '#1f77b4'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 2},
#         name=None,
#         size={'value': 20, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='fe4999f3-c656-4165-a079-1b36e90430b9',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='c2783ffe-73bf-4a34-a54b-27e1f8bc8e57',
#             callback=None,
#             data={'x': [1, 2, 3, 4, 5], 'y': [4, 6, 5, 3, 5]},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='43a905a5-23d4-4d76-af82-ac606c9ded3b',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='651b613e-f6cd-413d-926e-2d587480de7b',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %%
show(p)
# Out:
#   <div class="bk-root" id="98e283ce-6940-496d-a013-b965e1a1e238"></div>

# %% [markdown]
# ### Lines
# We explore the different kinds of lines on offer in Bokeh

# %%
p = figure(plot_width = 600, 
           plot_height = 300, 
           
           title = 'Lines')

# %% [markdown]
# #### Regular line
# This can be formatted in multiple ways:
# * the line_width can be used to adjust the thickness (default is 1)
# * the color can be set just as with markers
# * alpha value is configurable
# * line_dash allows the line to be set to something other than a solid line (the default) possible values are “dashed”, “dotted”, “dotdash”, “dashdot”

# %%
p.line([1, 2, 3, 4, 5], 
       [6, 7, 2, 4, 5], 
       
       line_width=4,
       color='red',
       alpha=0.6, 
       
       line_dash = 'dashed')

show(p)
# Out:
#   <div class="bk-root" id="21a707da-bb03-4fc1-8707-b78d33c71251"></div>

# %% [markdown]
# #### Step Glyph
# We use a step glyph here to draw a stepped line using the same coordinates as for the previous line. The mode for the stepped line determines when the step to the next y coordinate should occur. The default value is 'before', and other possible values are 'after' and 'center'.
#
# Notice how this varies from a regular line

# %%
p.step([1, 2, 3, 4, 5], 
       [6, 7, 2, 4, 5], 
       
       line_width=3,
       color='gold', 
       
       mode = 'before')

show(p)
# Out:
#   <div class="bk-root" id="0145ca7f-6e28-45d4-8c69-f9074df36e01"></div>

# %% [markdown]
# #### Missing data points
# When working with data sets, one may encounter missing data quite frequently. Bokeh's way of handling it is to disregard that point entirely, and create a disjointed line using the remaining points.
#
# Note that using None instead of float('nan') will treat the value as zero rather than null.

# %%
nan = float('nan')

p.line([1, 2, nan, 4, 5], 
       [6, 7, 2, 4, 5,], 
       
       line_width=4,
       
       color='magenta'
      )

show(p)
# Out:
#   <div class="bk-root" id="a024ba41-0e96-4eb2-abe1-7f5a0a91cbc6"></div>

# %% [markdown]
# #### Multiple lines
# A plotly figure has a multi_line glyph which allows one to draw multiple lines in the same call

# %%
p = figure(plot_width = 600, 
           plot_height = 300, 
           
           title = 'More Lines')

# %% [markdown]
# #### Here, multiple sets of X and Y coordinates are passed
# The format is( [[x0, x1...]], [[y0, y1...]] )
#
# Note that both lines are formatted in exactly the same way. One use case for a multi line is when you have categories of lines which need to appear similar in a figure in order to denote their category. So one could have several multi-lines in a plot, each representing a category or family of lines.

# %%
p.multi_line([[1, 3, 2], [3, 4, 6, 6]], 
             [[2, 1, 4], [4, 7, 8, 5]])

show(p)
# Out:
#   <div class="bk-root" id="4957c7c5-72b7-4891-8be2-3251e2827cad"></div>

# %%
p = figure(plot_width = 600, 
           plot_height = 300, 
           
           title = 'More Lines')

# %% [markdown]
# #### The lines in a multi-line can be formatted individually
# However, there may be reasons to format the lines in a multi-line individually. In that case, just pass a list of values for each property corresponding to the number of lines.
#
# We cannot pass a list of values for the line_dash property though

# %%
p.multi_line([[1, 3, 2], [3, 4, 6, 6]], 
             [[2, 1, 4], [4, 7, 8, 5]], 
             
             color=['green', 'orange'], 
             alpha=[0.8, 1], 
             line_width=[4, 3], 
             
             line_dash = 'dotted'
            )

show(p)
# Out:
#   <div class="bk-root" id="66c4d7af-baf1-44b6-a38f-37001c4d91bb"></div>
