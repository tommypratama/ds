# %%
from bokeh.plotting import figure
from bokeh.io import output_notebook,show

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="09b4a497-5044-4656-bd2c-fc7c0e47d48f">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Layouts
# We will create multiple figures and see how they can be arranged in a layout

# %% [markdown]
# #### Create a figure with circular markers

# %%
p1 = figure(plot_width = 240, 
            plot_height = 120, 
            
            title='First Plot')

p1.circle([1, 2, 3, 4, 5], 
         [6, 7, 3, 4, 5], 
         
         size = 8, 
         color = 'maroon'
        )
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='3b566691-ab3f-44d8-9aff-bd4b16c9747a',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='f776a872-4864-4b8a-8d3d-f73f5464a008',
#         callback=None,
#         data={'y': [6, 7, 3, 4, 5], 'x': [1, 2, 3, 4, 5]},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='1ccb9082-06be-4ac0-881f-4eb89efdd599',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='152ae8f7-a325-4aa0-a0a7-2196762661f6',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.markers.Circle(
#         id='236a1eb4-0d93-4165-bf3c-1f0665ecf382',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 1.0},
#         fill_color={'value': 'maroon'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 1.0},
#         line_cap='butt',
#         line_color={'value': 'maroon'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         radius=None,
#         radius_dimension='x',
#         size={'value': 8, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.markers.Circle(
#         id='9b5ea019-481f-4763-8586-b769a1f17fc6',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 0.1},
#         fill_color={'value': '#1f77b4'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 0.1},
#         line_cap='butt',
#         line_color={'value': '#1f77b4'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         radius=None,
#         radius_dimension='x',
#         size={'value': 8, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='bc82a296-4b3b-4e85-a210-2ecc65b6cc27',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='f776a872-4864-4b8a-8d3d-f73f5464a008',
#             callback=None,
#             data={'y': [6, 7, 3, 4, 5], 'x': [1, 2, 3, 4, 5]},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='1ccb9082-06be-4ac0-881f-4eb89efdd599',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='152ae8f7-a325-4aa0-a0a7-2196762661f6',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %% [markdown]
# #### The second figure shows a line

# %%
p2 = figure(plot_width = 240, 
            plot_height = 120, 
            
            title='Second Plot')

p2.line([1, 2, 3, 4, 5], 
        [6, 7, 2, 4, 5], 
        
        color='blue',
        line_dash = 'dashed')
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='9b20f605-2c9b-4f69-a3c0-054dee2d2c0c',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='19437a91-4671-4ada-a942-d8ed375ceace',
#         callback=None,
#         data={'y': [6, 7, 2, 4, 5], 'x': [1, 2, 3, 4, 5]},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='04993e59-567b-45b0-abda-e760a40dd4ca',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='3e3da0a7-7a9c-48fb-af9e-1d8279c2744e',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.glyphs.Line(
#         id='d30680bd-e8e1-4fea-a6bb-7e271000be43',
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha=1.0,
#         line_cap='butt',
#         line_color='blue',
#         line_dash=[6],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width=1,
#         name=None,
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.glyphs.Line(
#         id='3349d544-4e11-4042-a40d-0252ba992da5',
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha=0.1,
#         line_cap='butt',
#         line_color='#1f77b4',
#         line_dash=[6],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width=1,
#         name=None,
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='ab340b4b-dd60-4880-86c8-c8fd207d3d3a',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='19437a91-4671-4ada-a942-d8ed375ceace',
#             callback=None,
#             data={'y': [6, 7, 2, 4, 5], 'x': [1, 2, 3, 4, 5]},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='04993e59-567b-45b0-abda-e760a40dd4ca',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='3e3da0a7-7a9c-48fb-af9e-1d8279c2744e',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %% [markdown]
# #### The third figure contains two ellipses

# %%
p3 = figure(plot_width = 240, 
            plot_height = 120, 
            
            title='Third Plot')

p3.ellipse(x = [1, 4], 
          y = [3, 5], 
          
          width = [1, 3], 
          height = 2,
          
          color = 'tomato')
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='74e2bf7a-b0ee-4a60-b837-050e54cc1677',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='aef2cced-6455-4549-83bd-cf77cc9ae35b',
#         callback=None,
#         data={'y': [3, 5], 'x': [1, 4], 'width': [1, 3]},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='43bbc1c7-dde1-4abb-9525-307da4f18817',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='77002a54-cea3-45c6-aec7-524043d3cf0a',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.glyphs.Ellipse(
#         id='cac58079-06b2-4207-b76f-e11d42c1cffc',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 1.0},
#         fill_color={'value': 'tomato'},
#         height={'value': 2, 'units': 'data'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 1.0},
#         line_cap='butt',
#         line_color={'value': 'tomato'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         subscribed_events=[],
#         tags=[],
#         width={'field': 'width', 'units': 'data'},
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.glyphs.Ellipse(
#         id='418223b3-3cf8-49b2-a87c-59e8d82292d6',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 0.1},
#         fill_color={'value': '#1f77b4'},
#         height={'value': 2, 'units': 'data'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 0.1},
#         line_cap='butt',
#         line_color={'value': '#1f77b4'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         subscribed_events=[],
#         tags=[],
#         width={'field': 'width', 'units': 'data'},
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='8e6d93b9-5e69-49de-894b-63e67934f2a8',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='aef2cced-6455-4549-83bd-cf77cc9ae35b',
#             callback=None,
#             data={'y': [3, 5], 'x': [1, 4], 'width': [1, 3]},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='43bbc1c7-dde1-4abb-9525-307da4f18817',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='77002a54-cea3-45c6-aec7-524043d3cf0a',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %% [markdown]
# #### To arrange these figures, we import some layout functions
# We can arrange these figures in a single row or single column

# %%
from bokeh.layouts import row, column

# %% [markdown]
# #### The row function will place all figures in a single row

# %%
show(row(p1, p2, p3))
# Out:
#   <div class="bk-root" id="92e7617e-7bba-4c67-87d7-fb718d03dc7f"></div>

# %% [markdown]
# #### Place all figures in one column

# %%
show(column(p1, p2, p3))
# Out:
#   <div class="bk-root" id="28f35170-4464-466a-bbfe-3853c4f0fb18"></div>

# %% [markdown]
# #### Arrange the figures in a grid
# For this we import the gridplot function

# %%
from bokeh.layouts import gridplot

# %% [markdown]
# #### A 2D list of the figures will place them in a 2D grid
# The individual figures are referred to as the children of the layout objects

# %%
grid = gridplot([[p1, p2], [p3]])

# %%
show(grid)
# Out:
#   <div class="bk-root" id="63b85e31-f26e-4105-b391-60e00b1c0ce8"></div>

# %% [markdown]
# #### Blank spots in the grid
# We can set a child value to None if we would like to leave a spot on the grid empty

# %%
grid = gridplot([[p1, p2], [None,p3]])
show(grid)
# Out:
#   <div class="bk-root" id="87036f04-9149-4dee-880e-0acf818b7fbb"></div>

# %% [markdown]
# #### The layout function
# This allows us to have more complex layouts where we can stretch some figures to occupy the available space

# %%
from bokeh.layouts import layout

# %% [markdown]
# #### Define the layout
# When using layout, we pass along the child figures and specify a sizing_mode. This is what defines how the items in the layout will be scaled in order to fill the available space. The possible options are "fixed", "stretch_both", "scale_width", "scale_height", "scale_both"
#
# Here, the third plot is the only one on the 2nd row, so we set the sizing_mode to "scale_width" which will scale the third plot to occupy the entire width of the 2nd row. Since the width is effectively doubled for the 3rd plot, so is the height. The effect is that the third figure was originally defined to have the same dimensions as the first two, but will now be 4 times the size (2x2).

# %%
doc = layout([[p1, p2], [p3]], 
             sizing_mode = 'scale_width',
            )

# %%
show(doc)
# Out:
#   <div class="bk-root" id="963a13ac-6cf4-4b30-9ea7-82615bee41c0"></div>
